# %% [markdown]
# Using the dataset provided, develop the following visualizations using the right set of variables. (20 each)
#
# a. Histogram
#
# b. Bar chart
#
# c. Line chart
#
# d. Area chart
#
# e. Scatter plot

# %%
conda install pandas
# Out:
# ...
# Solving environment: ...working... done
#
# # All requested packages already installed.
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas
pandas.__version__
# Out:
# '1.3.4'

# %%
conda install matplotlib
# Out:
# ...
# Solving environment: ...working... done
#
# # All requested packages already installed.
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib
matplotlib.__version__
# Out:
# '3.4.3'

# %%
import pandas as pd
import matplotlib.pyplot as plt

mydata = pd.read_csv("data.csv")
mydata.fillna(100)
# Out:
#            Date  Temperature  Fuel_Price  MarkDown1  MarkDown2  MarkDown3  \
# 0        5/2/10        42.31       2.572     100.00     100.00     100.00
# 1       12/2/10        38.51       2.548     100.00     100.00     100.00
# 2    19/02/2010        39.93       2.514     100.00     100.00     100.00
# 3    26/02/2010        46.63       2.561     100.00     100.00     100.00
# 4        5/3/10        46.50       2.625     100.00     100.00     100.00
# ..          ...          ...         ...        ...        ...        ...
# 138  28/09/2012        76.08       3.666    3666.27       7.64       1.65
# 139     5/10/12        68.55       3.617    8077.89     100.00      18.22
# 140    12/10/12        62.99       3.601    2086.18     100.00       8.11
# 141  19/10/2012        67.97       3.594     950.33     100.00       4.93
# 142  26/10/2012        69.16       3.506    2585.85      31.75       6.00
#
#      MarkDown4  MarkDown5         CPI  Unemployment     Day type  \
# ...

# %%
mydata.columns
# Out:
# Index(['Date', 'Temperature', 'Fuel_Price', 'MarkDown1', 'MarkDown2',
#        'MarkDown3', 'MarkDown4', 'MarkDown5', 'CPI', 'Unemployment',
#        'Day type', 'dept_1 sales', 'dept_2 sales', 'dept_3 sales'],
#       dtype='object')

# %% [markdown]
# # Histogram

# %%
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('seaborn-bright')

# %matplotlib notebook

hist1 = mydata['dept_1 sales'].plot.hist(bins=20, figsize=(8,4), color='pink', ec="black", grid=True, alpha=0.95, legend=True)

hist1.grid(axis='y', alpha=0.6)
hist1.set_xlabel("Dept_1 Sales values")
hist1.set_title("Histogram- Distribution of Department_1_Sales")

plt.show()

hist1.figure.savefig("Histogram1.png")
# Out:
# <img src="data:image/png;base64,..." width="800">

# %% [markdown]
# # Histogram with mutiple variables in a single frame

# %%
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('seaborn-bright')

# %matplotlib notebook

hist2 = mydata[['dept_1 sales','dept_2 sales']].plot.hist(bins=20, figsize=(8,4), color=['pink', 'silver'], ec="black", grid=True, alpha=0.65, legend=True)

hist2.grid(axis='y', alpha=0.6)
hist2.set_xlabel("Dept_1,2 Sales values")
hist2.set_title("Histogram- Distribution of Department_1,2 Sales")

plt.show()

hist2.figure.savefig("Histogram2.png")
# Out:
# <img src="data:image/png;base64,..." width="800">

# %% [markdown]
# # Histogram with multiple variables in different frames

# %%
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('default')

# %matplotlib notebook

hist3 = mydata[['dept_1 sales','dept_2 sales','dept_3 sales']].hist(bins=20, figsize=(10,4), color="lavender", ec="black", grid=True)


plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %% [markdown]
# # BarChart

# %%
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('classic')

# %matplotlib notebook

barch = mydata.plot.bar(x='Day type', y='Temperature', color="red", figsize=(20,5), legend=True)
barch.figure.savefig("barchart.png")
# Out:
# <img src="data:image/png;base64,..." width="1600">

# %% [markdown]
# # LineChart

# %%
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('dark_background')

# %matplotlib notebook

line = mydata.plot.line(x='Date', y='CPI', color='lightblue', figsize=(12,6), legend=True)

line.figure.savefig("linechart.png")
# Out:
# <img src="data:image/png;base64,..." width="960">

# %%
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('dark_background')

# %matplotlib notebook

line2 = mydata.plot('Date', y= ['dept_1 sales','dept_2 sales','dept_3 sales'], figsize=(12,6))
line2.figure.savefig("linechart2.png")
# Out:
# <img src="data:image/png;base64,..." width="960">

# %% [markdown]
# # AreaChart

# %%
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('seaborn')

# %matplotlib notebook

area = mydata.plot.area(x='Date', y= ['Fuel_Price', 'Temperature'], color=['green', 'red','orange'], figsize=(10,4), alpha=0.5, stacked=False)

area.figure.savefig("AreaChart.png")
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('classic')

# %matplotlib notebook

area1 = mydata.plot.area(x='Date', figsize=(10,4), alpha=0.5, stacked=False)
plt.legend()
area1.figure.savefig("areachart1.png")
# Out:
# <img src="data:image/png;base64,..." width="800">

# %% [markdown]
# # ScatterPlot

# %%
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('ggplot')

# %matplotlib notebook


scatter = mydata.plot.scatter(x='Temperature', y='CPI', c=mydata.CPI, cmap='plasma', ec="black")
scatter.axvline(65, c=(.5,.5,.5), ls='--')
scatter.axhline(217, c=(.5,.5,.5), ls='--')
plt.show()

scatter.figure.savefig("scatterplot.png")
# Out:
# <img src="data:image/png;base64,..." width="640">
